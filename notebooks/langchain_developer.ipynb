# %%
# !python -m pip list all
# Out:
# Package                 Version     Editable project location
# ----------------------- ----------- --------------------------------------------
# agentic-ai              0.1.2       C:\Users\Himanshu.Tiwari\OneDrive\agentic_ai
# annotated-types         0.7.0
# anyio                   4.12.1
# asttokens               3.0.1
# azure-ai-agents         1.1.0
# azure-ai-projects       1.0.0
# azure-core              1.38.1
# azure-storage-blob      12.28.0
# certifi                 2026.1.4
# cffi                    2.0.0
# charset-normalizer      3.4.4
# colorama                0.4.6
# comm                    0.2.3
# contourpy               1.3.3
# cryptography            46.0.5
# cycler                  0.12.1
# debugpy                 1.8.20
# decorator               5.2.1
# executing               2.2.1
# fonttools               4.61.1
# h11                     0.16.0
# httpcore                1.0.9
# httpx                   0.28.1
# idna                    3.11
# ...
